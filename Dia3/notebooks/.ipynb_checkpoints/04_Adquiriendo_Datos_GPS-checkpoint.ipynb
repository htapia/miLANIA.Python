# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# # Adquiriendo datos de otros sensores
# En esta seccion continuamos con la adquisicion de datos usando los sensores de nuestros dispositivos moviles y su analisis.
#
# En general, el proceso de analisis de datos puede verse a partir de las siguintes etapas:
#
# * **Crear u obtener un conjunto de datos** para analizar
# * **Acceder a los datos** a partir de archivos (locales o en la nube)
# * **Preparar los datos** para asegurarnos que estan "limpios"
# * **Analizar los datos** para extraer informacion relevante
# * **Presentar los datos** en forma visual para comunicar ideas
# * **Distribuir los datos** para garantizar que nuestro trabajo es accesible a una audiencia y que ademas puede reproducirse

# %% [markdown]
# Ya hemos hecho un recorrido de cada de una de estas etapas utilizando diferentes alternativas para fuentes de informacion y para su analisis.
#
# En este ejemplo usaremos nuevamente sensores de nuestros dispositivos moviles para crear un conjunto de datos.

# %% [markdown]
# # Crear un conjunto de datos
#
# Primero hagamos un sencillo experimento. Todos ustedes saben extraer datos de geolocalizacion de sus aparatos? Yo tengo una aplicacion que genera y guarda estos datos en un archivo en formato `.csv`:

# %% [markdown]
# # Acceder a los datos
#
# Como hemos visto, acceder a los datos usando la libreria `pandas` es muy sencillo:

# %%
# %matplotlib inline

# %%
file_name = '../files/Sensor_record_20141024_124129_AndroSensor.csv'
sensorData = pd.read_csv(file_name, sep=';', header=1)
sensorData[:10]
# Out:
#    ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                  0.3172                  3.4141                  8.7843
# 1                 -0.1891                  2.2015                  8.6921
# 2                 -3.5291                  0.9697                  5.6515
# 3                -19.6127                  0.5878                  0.8092
# 4                 -9.6510                 -7.9428                  0.8763
# 5                  4.6424                 -9.1075                  1.7729
# 6                 -1.3372                -10.1586                  1.4904
# 7                 -4.7896                -15.4570                 -5.4145
# 8                  1.8711                 -3.8176                  1.5909
# 9                 -5.6611                -14.5974                 -4.6519
#
#    GRAVITY X (m/s²)  GRAVITY Y (m/s²)  GRAVITY Z (m/s²)  \
# 0            0.1504            3.2931            9.2360
# 1           -1.1530            2.7405            9.3451
# 2           -2.5132            3.0414            8.9780
# 3           -9.2648           -2.0155            2.5043
# 4           -9.5497           -2.0285            0.9264
# 5            0.6805           -9.4990           -2.3402
# 6            0.1363           -9.3628           -2.9136
# 7            0.2268           -9.7510           -1.0188
# 8            0.0988           -9.8058           -0.0847
# 9            0.8679           -8.9782            3.8483
#
#    LINEAR ACCELERATION X (m/s²)  LINEAR ACCELERATION Y (m/s²)  \
# 0                        0.1668                        0.1210
# 1                        0.9639                       -0.5390
# 2                       -1.0159                       -2.0717
# 3                      -10.3479                        2.6033
# 4                       -0.1013                       -5.9143
# 5                        3.9618                        0.3914
# 6                       -1.4735                       -0.7958
# 7                       -5.0164                       -5.7060
# 8                        1.7723                        5.9882
# 9                       -6.5289                       -5.6193
#
#    LINEAR ACCELERATION Z (m/s²)  GYROSCOPE X (rad/s)         ...           \
# 0                       -0.4516               0.0468         ...
# 1                       -0.6529               0.3147         ...
# 2                       -3.3265               0.1884         ...
# 3                       -1.6951               2.3041         ...
# 4                       -0.0501              -1.5049         ...
# 5                        4.1132               3.0478         ...
# 6                        4.4040              -0.9374         ...
# 7                       -4.3957               0.4050         ...
# 8                        1.6756              -0.1142         ...
# 9                       -8.5003               0.3006         ...
#
#    LOCATION Longitude :   LOCATION Altitude ( m)  LOCATION Speed ( Kmh)  \
# 0              -96.91544                     NaN                    NaN
# 1              -96.91544                     NaN                    NaN
# 2              -96.91544                     NaN                    NaN
# 3              -96.91544                     NaN                    NaN
# 4              -96.91544                     NaN                    NaN
# 5              -96.91544                     NaN                    NaN
# 6              -96.91544                     NaN                    NaN
# 7              -96.91544                     NaN                    NaN
# 8              -96.91544                     NaN                    NaN
# 9              -96.91544                     NaN                    NaN
#
#    LOCATION Accuracy ( m)  Satellites in range  Temperature (C)  Level (%)  \
# 0               188.70969                0 / 2             28.8         96
# 1               188.70969                0 / 4             28.8         96
# 2               188.70969                0 / 4             28.8         96
# 3               188.70969                0 / 3             28.8         96
# 4               188.70969                0 / 3             28.8         96
# 5               188.70969                0 / 3             28.8         96
# 6               188.70969                0 / 3             28.8         96
# 7               188.70969                0 / 3             28.8         96
# 8               188.70969                0 / 3             28.8         96
# 9               188.70969                0 / 3             28.8         96
#
#    Voltage (Volt)  Time since start in ms   YYYY-MO-DD HH-MI-SS_SSS
# 0           4.225                      222  2014-10-24 12:39:55:105
# 1           4.225                      805  2014-10-24 12:39:55:688
# 2           4.225                     1411  2014-10-24 12:39:56:294
# 3           4.225                     2503  2014-10-24 12:39:57:386
# 4           4.225                     3080  2014-10-24 12:39:57:963
# 5           4.225                     3780  2014-10-24 12:39:58:663
# 6           4.225                     4708  2014-10-24 12:39:59:591
# 7           4.225                     5265  2014-10-24 12:40:00:148
# 8           4.225                     5932  2014-10-24 12:40:00:815
# 9           4.225                     6496  2014-10-24 12:40:01:379
#
# [10 rows x 31 columns]

# %% [markdown]
# # Ejercicio: Crear y acceder a un cojunto de datos
#
# ## Obtengan sus datos de geolocalizacion
#
# Generen un archivo que contenga datos de geolocalizacion a partir de su dispositivo. Salgan a dar una vuelta al patio de LANIA y tomen datos en distintos lugares de la propiedad. Vuelvan en 5-7 minutos.
#
# ## Accedan a los datos
#
# Usando, preferentemente, la libreria pandas, guarden los datos de geolocalizacion que acaban de generar en una estructura de datos.

# %%
# Escriban su codigo y ejecuten la celda
geodatos = sensorData.iloc[:,20:22]
geodatos[:10]
# Out:
#    LOCATION Latitude :   LOCATION Longitude :
# 0             19.519932              -96.91544
# 1             19.519932              -96.91544
# 2             19.519932              -96.91544
# 3             19.519932              -96.91544
# 4             19.519932              -96.91544
# 5             19.519932              -96.91544
# 6             19.519932              -96.91544
# 7             19.519932              -96.91544
# 8             19.519932              -96.91544
# 9             19.519932              -96.91544

# %%
sensorData.plot(legend=False)

# %% [markdown]
# # Preparar, analizar y presentar datos
# Los datos recien adquiridos por el sensor no deberian necesitar preparacion (buscar valores no definidos, errores, etc.). Dado que son datos muy triviales no realizaremos ningun analisis sino unicamente los vamos a graficar para presentarlos.
#
# Como las coordenadas geograficas son pares de puntos, podemos graficarlos directamente:

# %%
geodatos.plot()

# %%
geodatos
# Out:
#      LOCATION Latitude :   LOCATION Longitude :
# 0               19.519932              -96.91544
# 1               19.519932              -96.91544
# 2               19.519932              -96.91544
# 3               19.519932              -96.91544
# 4               19.519932              -96.91544
# 5               19.519932              -96.91544
# 6               19.519932              -96.91544
# 7               19.519932              -96.91544
# 8               19.519932              -96.91544
# 9               19.519932              -96.91544
# 10              19.519932              -96.91544
# 11              19.519932              -96.91544
# 12              19.519932              -96.91544
# 13              19.519932              -96.91544
# 14              19.519932              -96.91544
# 15              19.519932              -96.91544
# 16              19.519932              -96.91544
# 17              19.519932              -96.91544
# 18              19.519932              -96.91544
# 19              19.519932              -96.91544
# 20              19.519932              -96.91544
# 21              19.519932              -96.91544
# 22              19.519932              -96.91544
# 23              19.519932              -96.91544
# 24              19.519932              -96.91544
# 25              19.519932              -96.91544
# 26              19.519932              -96.91544
# 27              19.519932              -96.91544
# 28              19.519932              -96.91544
# 29              19.519932              -96.91544
# ..                    ...                    ...
# 136             19.519932              -96.91544
# 137             19.519932              -96.91544
# 138             19.519932              -96.91544
# 139             19.519932              -96.91544
# 140             19.519932              -96.91544
# 141             19.519932              -96.91544
# 142             19.519932              -96.91544
# 143             19.519932              -96.91544
# 144             19.519932              -96.91544
# 145             19.519932              -96.91544
# 146             19.519932              -96.91544
# 147             19.519932              -96.91544
# 148             19.519932              -96.91544
# 149             19.519932              -96.91544
# 150             19.519932              -96.91544
# 151             19.519932              -96.91544
# 152             19.519932              -96.91544
# 153             19.519932              -96.91544
# 154             19.519932              -96.91544
# 155             19.519932              -96.91544
# 156             19.519932              -96.91544
# 157             19.519932              -96.91544
# 158             19.519932              -96.91544
# 159             19.519932              -96.91544
# 160             19.519932              -96.91544
# 161             19.519932              -96.91544
# 162             19.519932              -96.91544
# 163             19.519932              -96.91544
# 164             19.519932              -96.91544
# 165             19.519932              -96.91544
#
# [166 rows x 2 columns]

# %%
geodatos.keys()
# Out:
# Index([u'LOCATION Latitude : ', u'LOCATION Longitude : '], dtype='object')

# %%
geodatos.keys()[0]
# Out:
# 'LOCATION Latitude : '

# %%
geodatos.plot(x=geodatos.keys()[0], y=geodatos.keys()[1], kind='scatter')

# %%
geodatos.plot(x=0, y=1, kind='scatter')

# %% [markdown]
# No se ve muy interesante...estos son datos de coordenadas geograficas asi que quizas conviene usar un sistema apropiado...les presento `Basemap` una librearia para analizar datos geograficos. Para instalarla ejecuten el siguiente comando:
#
#     conda install basemap
#
# Si todo sale bien durante el proceso de instalacion deben ser capaces de importar la libreria escribiendo el siguiente comando en una celda:
#
#     from mpl_toolkits.basemap import Basemap

# %%
from mpl_toolkits.basemap import Basemap
from datetime import datetime

# %%
lats = geodatos.values[:,0]
lons =geodatos.values[:,1]

# timeStamp = sensorData['Timestamp']

# %%
m = Basemap(projection='hammer',lon_0=-90)

x, y = m(lons,lats)

m.drawmapboundary(fill_color='#99ffff')
m.fillcontinents(color='#cc9966',lake_color='#99ffff')
m.scatter(x,y,24,marker='o',color='k')
plt.text(x[-1],y[-1],'LANIA',color='b');

# %% [markdown]
# Ahora se ve un poco mejor! Podemos usar una proyeccion diferente:

# %%
map = Basemap(projection='mill',lon_0=-90)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(-90,90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(map.lonmin,map.lonmax+30,60),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.scatter(x,y,24,marker='o', color='b')
plt.text(x[-1],y[-1],'LANIA',color='b');

# %% [markdown]
# Podemos incluir la informacion temporal (obtenida con el sensor):

# %%
map = Basemap(projection='mill',lon_0=-90)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(-90,90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(map.lonmin,map.lonmax+30,60),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.scatter(x,y,24,marker='o', color='b')
plt.text(x[-1],y[-1],'LANIA',color='b');
date = datetime.utcnow()
# date=datetime.utcfromtimestamp(timeStamp.values[-1])
CS=map.nightshade(date)
plt.title('Day/Night Map for %s (UTC)' % date.strftime("%d %b %Y %H:%M:%S"));

# %% [markdown]
# Notan algo extrano en este mapa?

# %%
time_now = time.time()
print time_now, datetime.utcfromtimestamp(time_now)
time_data = datetime.utcfromtimestamp(timeStamp.values[-1])
print timeStamp.values[-1],time_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a81c65b8c690> in <module>()
# ----> 1 time_now = time.time()
#       2 print time_now, datetime.utcfromtimestamp(time_now)
#       3 time_data = datetime.utcfromtimestamp(timeStamp.values[-1])
#       4 print timeStamp.values[-1],time_data
#
# NameError: name 'time' is not defined

# %%
date_offset = datetime(year=2001, month=1, day=1)
print date_offset
timestamp2 = time.mktime(date_offset.timetuple())
print timestamp2, datetime.fromtimestamp(timestamp2)
# Out:
# 2001-01-01 00:00:00
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0cfd48f24caf> in <module>()
#       1 date_offset = datetime(year=2001, month=1, day=1)
#       2 print date_offset
# ----> 3 timestamp2 = time.mktime(date_offset.timetuple())
#       4 print timestamp2, datetime.fromtimestamp(timestamp2)
#
# NameError: name 'time' is not defined

# %%
time_real = timeStamp.values[-1] + timestamp2
print datetime.utcfromtimestamp(time_real)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-506c1cb4d1ec> in <module>()
# ----> 1 time_real = timeStamp.values[-1] + timestamp2
#       2 print datetime.utcfromtimestamp(time_real)
#
# NameError: name 'timestamp2' is not defined

# %% [markdown]
# Ahora copien el codigo de la celda que genero el ultimo mapa en una nueva celda y observen los cambios.

# %% [markdown]
# Veamos un poco mas de cerca donde esta LANIA:

# %%
map = Basemap(projection='mill',lon_0=-90, lat_0=0,
    llcrnrlon=-120, llcrnrlat=0.0,
    urcrnrlon=-70, urcrnrlat=30.75)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(map.latmin,map.latmax,10),labels=[1,1,1,1])
map.drawmeridians(np.arange(map.lonmin,map.lonmax,20),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'a
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.plot(x, y, 'bo', markersize=18)
plt.text(x[-1],y[-1],'LANIA');

# %% [markdown]
# Vamos a acercarnos un poco mas...

# %%
map = Basemap(lon_0=-90,lat_0=-0,
    llcrnrlon=-98, llcrnrlat=18.0,
    urcrnrlon=-96, urcrnrlat=20,
    resolution='l',area_thresh=0.01,projection='merc')
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawstates()
# map.drawparallels(np.arange(map.latmin,map.latmax,40),labels=[1,1,1,1])
# map.drawmeridians(np.arange(map.lonmin,map.lonmax,40),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'a
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons.values,lats.values)
map.plot(x, y, 'bo', markersize=18)
map.bluemarble()
plt.text(x[-1],y[-1],'LANIA');
